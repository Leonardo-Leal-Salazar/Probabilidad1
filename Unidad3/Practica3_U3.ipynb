# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad3/Practica3_U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 3
# ### Programa 3: Varianza y desviacion
# ### Falicitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar 🌇 🦊 🍂

# %%
import matplotlib.pyplot as plt
import math

# %%
import math
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

# Calcular E(X)
esperanza = 0
for i in range(len(x)):
    esperanza += x[i] * p[i]

# Calcular E(X^2)
esperanza_cuadrado = 0
for i in range(len(x)):
    esperanza_cuadrado += (x[i]**2) * p[i]

# Calcular varianza y desviacion estandar
varianza = esperanza_cuadrado - esperanza**2
desviacion = math.sqrt(varianza)

# Mostrar resultados
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion estandar = {desviacion:.2f}")
# Out:
# E(X) = 7.90
# E(X^2) = 64.10
# Varianza = 1.69
# Desviacion estandar = 1.30
