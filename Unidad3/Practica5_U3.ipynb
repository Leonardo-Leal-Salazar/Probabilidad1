# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad3/Practica5_U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 3
# ## Programa 5: Grafica de distribucion de probabilidad
# ### Falicitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar 🌇 🦊 🍂

# %%
# ------------------------------------------------------
# Grafica de una distribucion de probabilidad discreta
# con media, varianza y desviacion estandar
# ------------------------------------------------------
import matplotlib.pyplot as plt
import numpy as np

# %%
# Datos: Valores de la variable aleatoria y sus probabilidades
x = np.array([5, 6, 7, 8, 9, 10])
p = np.array([0.05, 0.10, 0.20, 0.30, 0.25, 0.10])

# Calculo del valor esperado (media)
esperanza = np.sum(x * p)

# Calculo de la esperanza del cuadrado
esperanza_cuadrada = np.sum(x**2 * p)

# Calculo de la varianza y desviacion estandar
varianza = esperanza_cuadrada - esperanza**2
desviacion = np.sqrt(varianza)

# %%
# Mostrar los resultados
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrada:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion estandar = {desviacion:.2f}")

# crear la grafica tipo 'stm' (tallos y hojas)
plt.stem(x, p, basefmt= "", linefmt="b-", markerfmt='bo')
plt.title("Distribucion de Probabilidad Discreta\ncon Media y Desviacion estandar")
plt.xlabel("Valor de la variable aleatoria X")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)

# Dibujar linea vertical de la media
plt.axvline(x=esperanza, color='r', linestyle='--', label=f'Media(X) = {esperanza:.2f}')

# Resalta el Rango de +- 1 desviacion estandar
plt.axvspan(esperanza - desviacion, esperanza + desviacion, color='r', alpha=0.2,
            label=f"+-1 Desv. Estandar (o = {desviacion:.2f})")

# Mostar leyenda y limites
plt.legend()
plt.ylim(0, max(p) + 0.05)
plt.xticks(x)

# Mostrar la grafica
plt.show()
# Out:
# E(X) = 7.90
# E(X^2) = 64.10
# Varianza = 1.69
# Desviacion estandar = 1.30
