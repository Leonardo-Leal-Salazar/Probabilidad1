# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad1/PRO_U1_Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Programa 2: **Tablas de frecuencias**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar 🌇 🦊 🍂

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [43, 27, 46, 42, 58, 58, 30, 20, 39, 48, 41, 49, 41, 38, 53, 67, 19, 58, 49, 44, 66, 22, 59, 63, 26, 19, 26, 32, 54, 60, 60, 68, 53, 23, 61, 34, 37, 22, 39, 40, 61, 52, 25, 69, 56, 32, 46, 24, 21, 32, 32, 63, 20, 59, 47, 47, 50, 44, 28, 56, 44, 43, 51, 59, 24, 29, 24, 30, 30, 50, 35, 37, 64, 22, 57, 59, 41, 52, 46, 22, 64, 53, 22, 64, 47, 50, 68, 45, 35, 63, 31, 54, 47, 51, 41, 45, 42, 51, 18, 60]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns = ['Edad'])
df.head() # Muestra los primeros 5 datos del registro
# Out:
#    Edad
# 0    43
# 1    27
# 2    46
# 3    42
# 4    58

# %%
# Calcular la lista de distribucion de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by = 'Edad')

# Imprimir la tabla de distribucion de frecuencias
print("Tabla de distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 46    18           1
# 22    19           2
# 21    20           2
# 40    21           1
# 0     22           5
# 37    23           1
# 8     24           3
# 42    25           1
# 30    26           2
# 34    27           1
# 39    28           1
# 43    29           1
# 5     30           3
# 45    31           1
# 4     32           4
# 36    34           1
# 16    35           2
# 17    37           2
# 32    38           1
# 19    39           2
# 35    40           1
# 2     41           4
# 24    42           2
# 23    43           2
# 7     44           3
# 25    45           2
# 6     46           3
# 3     47           4
# 33    48           1
# 20    49           2
# 13    50           3
# 14    51           3
# 27    52           2
# 11    53           3
# 29    54           2
# 18    56           2
# 44    57           1
# 12    58           3
# 1     59           4
# 9     60           3
# 26    61           2
# 10    63           3
# 15    64           3
# 38    66           1
# 31    67           1
# 28    68           2
# 41    69           1

# %%
tabla_frecuencias['Frec. Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 46    18           1            0.01
# 22    19           2            0.02
# 21    20           2            0.02
# 40    21           1            0.01
# 0     22           5            0.05
# 37    23           1            0.01
# 8     24           3            0.03
# 42    25           1            0.01
# 30    26           2            0.02
# 34    27           1            0.01
# 39    28           1            0.01
# 43    29           1            0.01
# 5     30           3            0.03
# 45    31           1            0.01
# 4     32           4            0.04
# 36    34           1            0.01
# 16    35           2            0.02
# 17    37           2            0.02
# 32    38           1            0.01
# 19    39           2            0.02
# 35    40           1            0.01
# 2     41           4            0.04
# 24    42           2            0.02
# 23    43           2            0.02
# 7     44           3            0.03
# 25    45           2            0.02
# 6     46           3            0.03
# 3     47           4            0.04
# 33    48           1            0.01
# 20    49           2            0.02
# 13    50           3            0.03
# 14    51           3            0.03
# 27    52           2            0.02
# 11    53           3            0.03
# 29    54           2            0.02
# 18    56           2            0.02
# 44    57           1            0.01
# 12    58           3            0.03
# 1     59           4            0.04
# 9     60           3            0.03
# 26    61           2            0.02
# 10    63           3            0.03
# 15    64           3            0.03
# 38    66           1            0.01
# 31    67           1            0.01
# 28    68           2            0.02
# 41    69           1            0.01

# %%
tabla_frecuencias['Frec. Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual
# 46    18           1            0.01               1.0
# 22    19           2            0.02               2.0
# 21    20           2            0.02               2.0
# 40    21           1            0.01               1.0
# 0     22           5            0.05               5.0
# 37    23           1            0.01               1.0
# 8     24           3            0.03               3.0
# 42    25           1            0.01               1.0
# 30    26           2            0.02               2.0
# 34    27           1            0.01               1.0
# 39    28           1            0.01               1.0
# 43    29           1            0.01               1.0
# 5     30           3            0.03               3.0
# 45    31           1            0.01               1.0
# 4     32           4            0.04               4.0
# 36    34           1            0.01               1.0
# 16    35           2            0.02               2.0
# 17    37           2            0.02               2.0
# 32    38           1            0.01               1.0
# 19    39           2            0.02               2.0
# 35    40           1            0.01               1.0
# 2     41           4            0.04               4.0
# 24    42           2            0.02               2.0
# 23    43           2            0.02               2.0
# 7     44           3            0.03               3.0
# 25    45           2            0.02               2.0
# 6     46           3            0.03               3.0
# 3     47           4            0.04               4.0
# 33    48           1            0.01               1.0
# 20    49           2            0.02               2.0
# 13    50           3            0.03               3.0
# 14    51           3            0.03               3.0
# 27    52           2            0.02               2.0
# 11    53           3            0.03               3.0
# 29    54           2            0.02               2.0
# 18    56           2            0.02               2.0
# 44    57           1            0.01               1.0
# 12    58           3            0.03               3.0
# 1     59           4            0.04               4.0
# 9     60           3            0.03               3.0
# 26    61           2            0.02               2.0
# 10    63           3            0.03               3.0
# 15    64           3            0.03               3.0
# 38    66           1            0.01               1.0
# 31    67           1            0.01               1.0
# 28    68           2            0.02               2.0
# 41    69           1            0.01               1.0

# %%
tabla_frecuencias['Frec. Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual  Frec. Acumulada
# 46    18           1            0.01               1.0                1
# 22    19           2            0.02               2.0                3
# 21    20           2            0.02               2.0                5
# 40    21           1            0.01               1.0                6
# 0     22           5            0.05               5.0               11
# 37    23           1            0.01               1.0               12
# 8     24           3            0.03               3.0               15
# 42    25           1            0.01               1.0               16
# 30    26           2            0.02               2.0               18
# 34    27           1            0.01               1.0               19
# 39    28           1            0.01               1.0               20
# 43    29           1            0.01               1.0               21
# 5     30           3            0.03               3.0               24
# 45    31           1            0.01               1.0               25
# 4     32           4            0.04               4.0               29
# 36    34           1            0.01               1.0               30
# 16    35           2            0.02               2.0               32
# 17    37           2            0.02               2.0               34
# 32    38           1            0.01               1.0               35
# 19    39           2            0.02               2.0               37
# 35    40           1            0.01               1.0               38
# 2     41           4            0.04               4.0               42
# 24    42           2            0.02               2.0               44
# 23    43           2            0.02               2.0               46
# 7     44           3            0.03               3.0               49
# 25    45           2            0.02               2.0               51
# 6     46           3            0.03               3.0               54
# 3     47           4            0.04               4.0               58
# 33    48           1            0.01               1.0               59
# 20    49           2            0.02               2.0               61
# 13    50           3            0.03               3.0               64
# 14    51           3            0.03               3.0               67
# 27    52           2            0.02               2.0               69
# 11    53           3            0.03               3.0               72
# 29    54           2            0.02               2.0               74
# 18    56           2            0.02               2.0               76
# 44    57           1            0.01               1.0               77
# 12    58           3            0.03               3.0               80
# 1     59           4            0.04               4.0               84
# 9     60           3            0.03               3.0               87
# 26    61           2            0.02               2.0               89
# 10    63           3            0.03               3.0               92
# 15    64           3            0.03               3.0               95
# 38    66           1            0.01               1.0               96
# 31    67           1            0.01               1.0               97
# 28    68           2            0.02               2.0               99
# 41    69           1            0.01               1.0              100

# %%
# Importamos la libreria with de funciones matematicas
import math

# %%
# Volvemos a usar la lista edades

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad' : edades})
df
# Out:
#     Edad
# 0     43
# 1     27
# 2     46
# 3     42
# 4     58
# ..   ...
# 95    45
# 96    42
# 97    51
# 98    18
# 99    60
#
# [100 rows x 1 columns]

# %%
# Calcular el numero  de intervalos utilizando la regla de Sturge
n = len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n , "\nNumero de intervalos = ", K)
# Out:
# Valor de n =  100
# Numero de intervalos =  7

# %%
# Crear la tabla de frecuencia
tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (39.857, 47.143]    21
# 1  (47.143, 54.429]    16
# 2  (17.948, 25.286]    16
# 3  (54.429, 61.714]    15
# 4  (25.286, 32.571]    13
# 5    (61.714, 69.0]    11
# 6  (32.571, 39.857]     8

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.948, 25.286]    16
# 4  (25.286, 32.571]    13
# 6  (32.571, 39.857]     8
# 0  (39.857, 47.143]    21
# 1  (47.143, 54.429]    16
# 3  (54.429, 61.714]    15
# 5    (61.714, 69.0]    11

# %%
# Generar columnas siguientes
import matplotlib.pyplot as plt
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec']/n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec']/n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
plt.hist(edades,alpha=0.5)
plt.title("histogramas de edades basados en la funcion de matplotlib con valores estandar")
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac
# 2  (17.948, 25.286]    16      0.16       16.0     0.16         16.0
# 4  (25.286, 32.571]    13      0.13       13.0     0.29         29.0
# 6  (32.571, 39.857]     8      0.08        8.0     0.37         37.0
# 0  (39.857, 47.143]    21      0.21       21.0     0.58         58.0
# 1  (47.143, 54.429]    16      0.16       16.0     0.74         74.0
# 3  (54.429, 61.714]    15      0.15       15.0     0.89         89.0
# 5    (61.714, 69.0]    11      0.11       11.0     1.00        100.0
# Text(0.5, 1.0, 'histogramas de edades basados en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
