# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad1/PRO_U1_Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar
# ### Programa 1: **Estadistica basica e Histrograma**

# %%
from statistics import *

# %%
# Lista de calificaciones del grupo a de probabilidad y estadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# la funcion type nos devuelve el tipo de dato de la variable
type(grupoa)
# Out:
# list

# %%
# Sacar la medioa de las calificaciones con una formula
promedio = sum(grupoa)/ len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
# Utilizar la funcion mean que esta en la libreria statistics para sacar
# el promedio
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
# Determinar el valor de la mediana con la funcion median
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
# Determinar el valor de la moda con la funcion mode
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
# En caso de que exista mas de una moda, se puede emplear la funcion
# multimode para seber las multiples modas que pueden existir
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
# Definimos una variable llamada tiempos100mts de tipo lista, que
# contiene los tiempos que tardaron los 10 alumnos para correr 100 metros
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65,
                 15.10, 17.20]

# Desplegamos los valores de la lista
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
# Sacar las medidas de tendencia
print("El tiempo promedio de los corredores es = ", mean(tiempos100mts))
print("La mediana de los tiempos de los corredores es = ", median(tiempos100mts))
print("La moda de los tiempos de los corredores es = ", mode(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es =  17.322
# La mediana de los tiempos de los corredores es =  17.2
# La moda de los tiempos de los corredores es =  15.1

# %%
# Libreria para generar numeros aleatoreos
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [90.68, 55.12, 84.31, 77.36, 86.7, 98.96, 89.52, 75.54, 76.71, 74.21, 83.78, 69.06, 77.14, 69.77, 57.14, 56.26, 86.99, 76.1, 82.19, 83.29, 83.42, 62.26, 68.23, 56.09, 79.05, 95.54, 92.74, 53.01, 82.99, 74.75, 63.23, 93.65, 97.89, 80.11, 81.95, 86.59, 88.77, 76.81, 72.89, 67.98, 51.79, 75.7, 51.84, 79.82, 80.18, 52.34, 82.19, 87.84, 61.83, 66.26, 54.69, 63.98, 53.26, 56.34, 57.29, 65.22, 65.11, 89.84, 72.34, 63.51, 66.23, 68.65, 66.71, 89.29, 68.28, 55.26, 75.11, 99.76, 85.76, 68.74, 85.49, 85.05, 77.37, 56.64, 86.94, 59.03, 74.83, 89.73, 79.83, 70.26, 77.52, 89.48, 92.44, 83.01, 82.16, 72.27, 75.69, 93.77, 62.79, 82.22, 54.1, 85.1, 81.85, 97.3, 88.37, 69.72, 86.39, 51.53, 67.42, 93.78]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(70, 100), 2 )
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [92.19, 77.79, 76.08, 75.37, 97.61, 92.79, 92.03, 83.36, 72.65, 84.58, 97.22, 91.86, 75.74, 93.83, 97.32, 90.33, 89.24, 99.61, 95.31, 86.96, 79.0, 93.13, 71.74, 89.5, 84.67, 92.92, 98.98, 84.65, 82.91, 70.94, 91.77, 73.82, 96.37, 95.95, 90.88, 87.52, 74.24, 72.71, 74.4, 74.77, 97.05, 82.95, 87.15, 88.87, 84.52, 91.24, 74.45, 81.69, 72.77, 74.51, 87.26, 94.21, 72.88, 96.03, 99.46, 77.96, 76.43, 91.96, 78.01, 88.23, 76.93, 89.2, 80.24, 76.49, 83.22, 71.89, 83.26, 73.28, 89.12, 92.35, 81.23, 74.05, 98.65, 92.93, 91.12, 91.74, 85.17, 70.95, 94.15, 79.41, 81.78, 70.67, 89.03, 89.1, 72.79, 73.15, 88.37, 82.48, 77.78, 86.05, 84.55, 97.17, 86.7, 78.33, 92.23, 88.86, 94.4, 78.46, 99.89, 74.59]

# %%
# Libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la Fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la Fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 2')

# %%
print("Valores de la fabrica 1")
print("La media es: ", mean(fabrica1))
print("La mediana es: ", median(fabrica1))
print("La moda es: ", mode(fabrica1))
# Out:
# Valores de la fabrica 1
# La media es:  75.3602
# La mediana es:  76.75999999999999
# La moda es:  82.19

# %%
print("Valores de la fabrica 2")
print("La media es: ", mean(fabrica2))
print("La mediana es: ", median(fabrica2))
print("La moda es: ", mode(fabrica2))
# Out:
# Valores de la fabrica 2
# La media es:  85.0213
# La mediana es:  85.61
# La moda es:  92.19

# %%
# Generar 2 subplot de 1 renglon por 2 columnas para
# desplegar los 2 histogramas, una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
