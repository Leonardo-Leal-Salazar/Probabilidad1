# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad1/PRO_U1_Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Programa 2: **Maximo, minimo, Rango y dispercion de datos**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
# Generamos 100 numeros aleatorios que representan la produccion
# en metros de tela de 100 dias
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [50.62, 76.99, 56.0, 61.38, 87.53, 53.45, 58.34, 58.0, 98.34, 66.76, 84.52, 53.46, 97.23, 64.81, 79.01, 93.49, 87.07, 87.26, 59.69, 67.4, 94.21, 52.09, 94.74, 81.35, 58.79, 80.03, 60.42, 50.18, 79.66, 87.1, 50.6, 56.33, 85.4, 99.98, 86.17, 99.19, 67.16, 57.62, 72.88, 92.93, 66.02, 50.49, 53.54, 63.68, 85.18, 89.75, 95.83, 76.64, 91.81, 93.93, 98.83, 93.27, 98.31, 80.96, 62.57, 74.18, 51.36, 66.81, 91.08, 97.53, 83.83, 56.85, 57.86, 97.83, 98.11, 96.49, 98.3, 97.35, 90.39, 80.35, 88.03, 83.55, 86.15, 92.29, 97.93, 76.64, 76.44, 92.09, 73.9, 96.17, 83.58, 58.13, 61.02, 62.89, 65.97, 93.91, 51.38, 96.96, 63.32, 69.9, 63.09, 65.72, 96.27, 65.61, 54.61, 55.94, 59.56, 52.95, 75.16, 86.49]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2 )
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [65.26, 62.33, 74.31, 78.26, 84.7, 75.56, 83.01, 65.94, 79.71, 87.93, 90.4, 71.87, 64.37, 84.17, 64.03, 93.66, 82.32, 79.88, 51.9, 55.82, 74.64, 69.57, 88.3, 93.13, 59.74, 57.08, 72.17, 65.1, 95.68, 56.28, 78.72, 98.13, 75.13, 85.98, 71.77, 87.8, 58.85, 90.72, 99.08, 81.41, 76.07, 93.19, 51.82, 57.09, 51.38, 76.95, 66.79, 76.98, 90.89, 73.94, 80.24, 58.57, 51.31, 59.19, 94.69, 87.2, 59.88, 61.87, 93.41, 92.41, 88.87, 52.24, 60.91, 62.77, 59.44, 87.1, 60.97, 90.87, 52.88, 81.46, 64.91, 90.73, 97.4, 92.18, 82.96, 90.94, 93.36, 53.83, 57.32, 96.4, 81.62, 82.96, 57.65, 70.77, 69.52, 65.76, 61.05, 78.58, 80.93, 67.2, 93.49, 67.43, 59.18, 98.02, 66.6, 74.69, 62.5, 97.96, 92.69, 77.77]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)

print("Estadistica descriptiva de la fabrica 1 \n",
      "Media =", media1,
      "\n Mediana =", media1,
      "\n Moda =", moda1,
      "\n Maximo =", maximo1,
      "\n Minimo =", minimo1,
      "\n Rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 76.3296
#  Mediana = 76.3296
#  Moda = 76.64
#  Maximo = 99.98
#  Minimo = 50.18
#  Rango = 49.800000000000004
# 16.34807862061651

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)

print("Estadistica descriptiva de la fabrica 2 \n",
      "Media =", media2,
      "\n Mediana =", media2,
      "\n Moda =", moda2,
      "\n Maximo =", maximo2,
      "\n Minimo =", minimo2,
      "\n Rango =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  Media = 75.3249
#  Mediana = 75.3249
#  Moda = 82.96
#  Maximo = 99.08
#  Minimo = 51.31
#  Rango = 47.769999999999996
# 14.154034260538047

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='c', edgecolor= "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='c', edgecolor= "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()

# %%
import seaborn as sns

# %%
# La densidad grafica es una forma de vosualizar la distribucion de datos en
# un intervalo o periodo de tiempo continuo.
# Se basa en un histograma que usa el suavizado de kernel para trazar valor,
# lo que permite obtener distribuciones mas suaves al reducir el ruido.
# Una curva de densidad muestra la ubicacion de la media y la mediana de una distribucion

sns.histplot(x = fabrica1, kde = True, color='c', kde_kws= {'bw_adjust':0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(x = fabrica2, kde = True, color='c', kde_kws= {'bw_adjust':0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
