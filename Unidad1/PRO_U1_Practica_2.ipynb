# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad1/PRO_U1_Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Programa 2: **Maximo, minimo, Rango y dispercion de datos**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
# Generamos 100 numeros aleatorios que representan la produccion
# en metros de tela de 100 dias
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [70.98, 60.46, 70.59, 63.18, 89.38, 85.52, 71.58, 93.28, 66.0, 70.03, 92.22, 83.17, 95.51, 79.45, 81.98, 99.74, 77.16, 80.03, 73.65, 56.47, 98.16, 59.64, 68.03, 74.45, 82.3, 56.83, 86.31, 54.44, 96.24, 61.0, 73.82, 92.45, 80.29, 53.24, 70.13, 70.62, 88.04, 74.34, 50.67, 53.76, 58.36, 89.73, 65.89, 63.59, 82.7, 91.68, 89.91, 77.25, 62.82, 70.08, 59.28, 64.09, 68.12, 75.93, 90.63, 63.61, 60.72, 59.24, 87.91, 61.03, 65.52, 58.26, 62.44, 99.7, 72.9, 71.58, 87.96, 50.08, 90.56, 87.73, 58.77, 69.21, 98.95, 77.59, 86.55, 87.32, 72.62, 58.39, 89.89, 61.51, 77.64, 77.4, 96.55, 80.84, 94.63, 74.57, 97.46, 61.58, 64.53, 56.1, 57.12, 94.11, 95.27, 75.71, 78.48, 67.87, 83.61, 92.79, 81.98, 56.28]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2 )
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [53.08, 66.06, 90.57, 58.79, 75.45, 90.21, 74.32, 91.43, 50.51, 98.7, 78.96, 96.99, 96.3, 57.32, 91.16, 54.9, 76.54, 63.89, 94.02, 60.95, 78.15, 52.1, 57.84, 88.42, 82.97, 69.56, 58.16, 64.88, 67.13, 55.5, 51.44, 88.41, 88.93, 71.29, 52.69, 62.9, 76.68, 94.06, 66.55, 74.21, 72.33, 69.56, 89.56, 58.03, 68.38, 93.71, 58.16, 70.16, 50.58, 64.09, 91.65, 76.06, 63.41, 92.92, 84.79, 61.45, 77.08, 84.92, 74.96, 74.15, 57.12, 87.88, 58.44, 93.0, 80.44, 59.56, 51.3, 69.45, 77.24, 97.46, 59.84, 66.07, 96.44, 64.57, 81.38, 97.09, 98.32, 89.96, 88.94, 60.63, 92.15, 62.63, 68.73, 88.84, 51.41, 71.87, 90.62, 67.7, 65.13, 76.23, 69.13, 80.07, 71.17, 51.43, 93.02, 72.15, 52.18, 68.23, 95.61, 56.47]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)

print("Estadistica descriptiva de la fabrica 1 \n",
      "Media =", media1,
      "\n Mediana =", media1,
      "\n Moda =", moda1,
      "\n Maximo =", maximo1,
      "\n Minimo =", minimo1,
      "\n Rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 75.1976
#  Mediana = 75.1976
#  Moda = 71.58
#  Maximo = 99.74
#  Minimo = 50.08
#  Rango = 49.66
# 13.742485485279994

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)

print("Estadistica descriptiva de la fabrica 2 \n",
      "Media =", media2,
      "\n Mediana =", media2,
      "\n Moda =", moda2,
      "\n Maximo =", maximo2,
      "\n Minimo =", minimo2,
      "\n Rango =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  Media = 73.7787
#  Mediana = 73.7787
#  Moda = 69.56
#  Maximo = 98.7
#  Minimo = 50.51
#  Rango = 48.190000000000005
# 14.629316674873689
