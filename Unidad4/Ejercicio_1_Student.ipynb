# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad4/Ejercicio_1_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 4
# ## Programa 8: Ejercicio 1
# ### Falicitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar 🌇 🦊 🍂

# %%
import numpy as np
from scipy.stats import t
import matplotlib.pyplot as plt

# Datos de la muestra
data = np.array([118, 125, 130, 128, 122, 135, 126, 132, 129, 120, 127, 124])
n = len(data)
media = np.mean(data)
desv_std = np.std(data, ddof=1) # Desviacion estandar muestral (ddof=1)
alpha = 0.05 # Nivel de significancia (95% de confianza)
df = n-1

# valor critico de t (dos colas)
t_critico = t.ppf(1 - alpha/2, df)

# Error estandar
error = t_critico * (desv_std / np.sqrt(n))

# Intervalo de confianza
lim_inf = media - error
lim_sup = media + error

print(f"Media muestral = {media:.2f} mmHg")
print(f"Desviacion estandar = {desv_std:.2f} mmHg")
print(f"Grados de libertad = {df}")
print(f"Valor critico t = {t_critico:.3f}")
print(f"Intervalo de confianza 95%: [{lim_inf:.2f}, {lim_sup:.2f}] mmHg")

# Graficar
x = np.linspace(media - 3*desv_std, media + 3*desv_std, 200)
y = t.pdf((x - media) / (desv_std / np.sqrt(n)), df)
plt.figure(figsize=(8, 5))
plt.plot(x, y, color='navy', label='Distribucion t de la memoria muestral')
plt.axvline(lim_inf, color='red', linestyle='--', label='Limite inferior')
plt.axvline(lim_sup, color= 'red', linestyle='--', label='Limite superior')
plt.axvline(media, color='green', linestyle='-', label='Media Muestral')
plt.title("Intervalo de confianza del 95% para la media (t de Student)")
plt.xlabel("Presion arterial (mmHg)")
plt.ylabel("Densidad de probabiidad")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Media muestral = 126.33 mmHg
# Desviacion estandar = 4.92 mmHg
# Grados de libertad = 11
# Valor critico t = 2.201
# Intervalo de confianza 95%: [123.20, 129.46] mmHg
