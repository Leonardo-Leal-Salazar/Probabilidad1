# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad4/Ejercicio_1_po.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 4
# ## Programa 6: Ejercicio 1
# ### Falicitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar 🌇 🦊 🍂

# %%
from scipy.stats import poisson

# Parametros de la distribucion de Possion
media_accidentes = 2

# Parte 1: Probabilidad de que no haya accidentes en 1 semana
probabilidad_0_accidentes = poisson.pmf(0, media_accidentes)

print("1. Probabilidad de que no haya accidentes en 1 semana:", probabilidad_0_accidentes)

# Parte 2: Probabilidad de que la suma haya tres accidentes en 2 semanas
# Convertimos la media a una media para 2 semanas
media_2_semanas = media_accidentes * 2

# Calculamos la probabilidad acumulada hasta 3 accidentes por 2 semanas
probabilidad_3_o_menos_accidentes = poisson.pmf(3, media_2_semanas)

print("2. Probabilidad de que a lo sumo haya tres accidentes en 2 semanas:", probabilidad_3_o_menos_accidentes)
# Out:
# 1. Probabilidad de que no haya accidentes en 1 semana: 0.1353352832366127
# 2. Probabilidad de que a lo sumo haya tres accidentes en 2 semanas: 0.19536681481316454
