# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Leal-Salazar/Probabilidad1/blob/main/Unidad4/Ejercicio_2_bi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 4
# ## Programa 4: Ejercicio 2
# ### Falicitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Erik Leonardo Leal Salazar 🌇 🦊 🍂

# %%
from scipy.stats import binom

# Parametros de la distribucion binomial
n = 10
p = 0.10
x = 2

# Calcular la probabilidad de la varible aleatoria x = 2
probabilidad_x_2 = binom.pmf(x, n, p)

print("La probabilidad de que la variable aleatoria x sea igual a 2 es:", probabilidad_x_2)
# Out:
# La probabilidad de que la variable aleatoria x sea igual a 2 es: 0.19371024450000007
